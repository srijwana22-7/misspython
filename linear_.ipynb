# %% [markdown]
# <a href="https://colab.research.google.com/github/srijwana22-7/misspython/blob/main/linear_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
A=[[1],[2],[3],[4],[5]]
B=[20,35,38,45,50]

model= LinearRegression()
model.fit(A,B)
prediction=model.predict([[7]])
print(prediction)
# Out:
# [65.6]
